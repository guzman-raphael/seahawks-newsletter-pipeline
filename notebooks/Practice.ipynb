# %%
cd ..
# Out:
# /Users/davidgodinez/github/seahawks-newsletter-pipeline

# %%
from pipeline import image
# Out:
# Connecting davidgodinez@localhost:3306

# %%
image.Image()
# Out:
# *image_id    image
# +----------+ +--------+
# 1            =BLOB=
#  (Total: 1)

# %%
from matplotlib import pyplot as plt

# %%
# %matplotlib inline

# %%
data = (image.Image).fetch1('image')

# %%
plt.imshow(data)

# %%
data_2 = (image.TransformedImage).fetch1('transformed_image')

# %%
plt.imshow(data_2)
